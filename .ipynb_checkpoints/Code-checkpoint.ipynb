# %% [markdown]
# Este código carga datos de cáncer de mama, crea modelos de clasificación con Random Forest, Bagging y Extra Trees, y calcula la precisión. También muestra gráficos de importancia de características y otros visualizaciones de datos.
# ------------------------------------------------------------------------------------------------------------------------------

# %%
#bibliotecas
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from tabulate import tabulate
import numpy as np
import seaborn as sns

# %%
# !pip install tabulate
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Este código carga el conjunto de datos de cáncer de mama utilizando la función `load_breast_cancer()` de scikit-learn. Luego, se asignan las características (X) y las etiquetas (y) del conjunto de datos. Además, se almacenan los nombres de las características en la variable `feature_names`.
# ------------------------------------------------------------------------------------------------------------------------------

# %%
#conjunto de datos
data = load_breast_cancer()
X = data.data
y = data.target
feature_names = data.feature_names

# %% [markdown]
# En este código, se entrena un modelo de Random Forests y se visualiza la importancia de las características mediante un gráfico de barras horizontales.
# ------------------------------------------------------------------------------------------------------------------------------

# %%
# Entreno el Random Forests + grafica
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X, y)

importances = rf.feature_importances_
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
importance_df = importance_df.sort_values('Importance', ascending=False).reset_index(drop=True)

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.barh(importance_df['Feature'], importance_df['Importance'], color='steelblue')
ax.set_xlim(0, 1)
ax.set_xlabel('Importancia')
ax.set_ylabel('Característica')

for i, v in enumerate(importance_df['Importance']):
    ax.text(v + 0.01, i, f'{v:.3f}', color='black', va='center')

plt.title('Importancia de características con Random Forests')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_13048/701399180.py:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# El código entrena diferentes modelos de clasificación utilizando el conjunto de datos y calcula la precisión de cada modelo. También muestra la importancia de las características y proporciona un resumen de clasificación con las métricas de precisión. Además, calcula estadísticas descriptivas sobre la importancia de las características.
# ------------------------------------------------------------------------------------------------------------------------------

# %%
#DATOOOOOS IMPORTANCIA + RESUMEN DE DATOS Y PRECISION + ESTADISTICAS

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

bagging = BaggingClassifier(random_state=42)
bagging.fit(X_train, y_train)

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

et = ExtraTreesClassifier(random_state=42)
et.fit(X_train, y_train)

y_pred_bagging = bagging.predict(X_test)
y_pred_rf = rf.predict(X_test)
y_pred_et = et.predict(X_test)

accuracy_bagging = accuracy_score(y_test, y_pred_bagging)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
accuracy_et = accuracy_score(y_test, y_pred_et)

baseline_prediction = np.bincount(y_train).argmax()
baseline_accuracy = accuracy_score(y_test, np.full_like(y_test, baseline_prediction))

results = [
    ["Clasificador", "Precisión", "Precisión con Línea Base"],
    ["Bagging", accuracy_bagging, baseline_accuracy],
    ["Random Forests", accuracy_rf, baseline_accuracy],
    ["Extra Trees", accuracy_et, baseline_accuracy]
]

feature_importance_table = [
    ["Índice", "Nombre de Característica", "Importancia"]
]

sorted_indices = np.argsort(rf.feature_importances_)[::-1]
for i, feature_index in enumerate(sorted_indices):
    feature_name = data.feature_names[feature_index]
    feature_importance = rf.feature_importances_[feature_index]
    feature_importance_table.append([i+1, feature_name, feature_importance])

print("\nImportancia de características (Random Forests):")
print(tabulate(feature_importance_table, headers="firstrow", tablefmt="grid"))

classification_summary = [
    ["Clasificador", "Precisión", "Precisión con Línea Base"],
    ["Bagging", round(accuracy_bagging, 4), round(baseline_accuracy, 4)],
    ["Random Forests", round(accuracy_rf, 4), round(baseline_accuracy, 4)],
    ["Extra Trees", round(accuracy_et, 4), round(baseline_accuracy, 4)]
]

print("\nResumen de clasificación:")
print(tabulate(classification_summary, headers="firstrow", tablefmt="grid"))

importance_stats = [
    ["Mínimo", round(np.min(rf.feature_importances_), 4)],
    ["Máximo", round(np.max(rf.feature_importances_), 4)],
    ["Media", round(np.mean(rf.feature_importances_), 4)],
    ["Mediana", round(np.median(rf.feature_importances_), 4)],
    ["Desviación estándar", round(np.std(rf.feature_importances_), 4)]
]

print("\nEstadísticas descriptivas de importancia de características:")
print(tabulate(importance_stats, headers=["Estadística", "Valor"], tablefmt="grid"))
# Out:
# Importancia de características (Random Forests):
# +----------+----------------------------+---------------+
# |   Índice | Nombre de Característica   |   Importancia |
# +==========+============================+===============+
# |        1 | mean concave points        |    0.141934   |
# +----------+----------------------------+---------------+
# |        2 | worst concave points       |    0.127136   |
# +----------+----------------------------+---------------+
# |        3 | worst area                 |    0.118217   |
# +----------+----------------------------+---------------+
# |        4 | mean concavity             |    0.080557   |
# +----------+----------------------------+---------------+
# |        5 | worst radius               |    0.0779747  |
# +----------+----------------------------+---------------+
# |        6 | worst perimeter            |    0.0742921  |
# +----------+----------------------------+---------------+
# ...

# %% [markdown]
# Se calculan y grafican las matrices de confusión para cada uno de los tres algoritmos de clasificación: Bagging, Random Forests y Extra Trees. Cada matriz muestra la cantidad de predicciones correctas e incorrectas realizadas por el modelo en función de las etiquetas reales y las etiquetas predichas.
# ------------------------------------------------------------------------------------------------------------------------------

# %%
# MATRICEZ DE CONFUSION + CALCULOS DE CONFUSION CON LOS 3 ALGORITMOS
confusion_bagging = confusion_matrix(y_test, y_pred_bagging)
confusion_rf = confusion_matrix(y_test, y_pred_rf)
confusion_et = confusion_matrix(y_test, y_pred_et)

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
sns.heatmap(confusion_bagging, annot=True, fmt='d', cmap='Blues', ax=axes[0])
sns.heatmap(confusion_rf, annot=True, fmt='d', cmap='Blues', ax=axes[1])
sns.heatmap(confusion_et, annot=True, fmt='d', cmap='Blues', ax=axes[2])
axes[0].set_title("Bagging")
axes[1].set_title("Random Forests")
axes[2].set_title("Extra Trees")
axes[0].set_xlabel('Predicted labels')
axes[0].set_ylabel('True labels')
plt.suptitle("Matrices de Confusión")
plt.tight_layout()
plt.show()

# %% [markdown]
# Se grafican los histogramas de dos características del conjunto de datos. El primer histograma muestra la distribución de la primera característica, y el segundo histograma muestra la distribución de la segunda característica. Estas visualizaciones nos permiten observar la forma y la dispersión de los datos en cada una de las características.
# ------------------------------------------------------------------------------------------------------------------------------

# %%
# Graficar histplot
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
sns.histplot(X[:, 0], ax=axes[0])
sns.histplot(X[:, 1], ax=axes[1])
axes[0].set_title(f"Distribución de {feature_names[0]}")
axes[1].set_title(f"Distribución de {feature_names[1]}")
plt.suptitle("Distplots de Características")
plt.tight_layout()
plt.show()

# %% [markdown]
# Se realiza el análisis de componentes principales (PCA) en el conjunto de datos. Se reduce la dimensionalidad del conjunto de entrenamiento y prueba a 10 componentes principales utilizando PCA. Luego se entrenan los clasificadores Bagging, Random Forests y Extra Trees utilizando los datos transformados por PCA. Se obtiene la precisión de cada clasificador utilizando los datos de prueba transformados por PCA. También se calcula la precisión de la línea base utilizando la predicción constante de la clase mayoritaria. Se muestra un resumen de clasificación con las precisiones obtenidas y se muestra el número de muestras en el conjunto de entrenamiento.
# ------------------------------------------------------------------------------------------------------------------------------

# %%
#PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
bagging = BaggingClassifier(random_state=42)
bagging.fit(X_train_pca, y_train)

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train_pca, y_train)

et = ExtraTreesClassifier(random_state=42)
et.fit(X_train_pca, y_train)

y_pred_bagging_pca = bagging.predict(X_test_pca)
y_pred_rf_pca = rf.predict(X_test_pca)
y_pred_et_pca = et.predict(X_test_pca)

accuracy_bagging_pca = accuracy_score(y_test, y_pred_bagging_pca)
accuracy_rf_pca = accuracy_score(y_test, y_pred_rf_pca)
accuracy_et_pca = accuracy_score(y_test, y_pred_et_pca)

baseline_prediction_pca = np.bincount(y_train).argmax()
baseline_accuracy_pca = accuracy_score(y_test, np.full_like(y_test, baseline_prediction))

# %%
classification_summary = [
    ["Clasificador", "Precisión con PCA", "Precisión con Línea Base con PCA"],
    ["Bagging", round(accuracy_bagging_pca, 4), round(baseline_accuracy_pca, 4)],
    ["Random Forests", round(accuracy_rf_pca, 4), round(baseline_accuracy_pca, 4)],
    ["Extra Trees", round(accuracy_et_pca, 4), round(baseline_accuracy_pca, 4)]
]

print("\nResumen de clasificación:")
print(tabulate(classification_summary, headers="firstrow", tablefmt="grid"))
# Out:
# Resumen de clasificación:
# +----------------+---------------------+------------------------------------+
# | Clasificador   |   Precisión con PCA |   Precisión con Línea Base con PCA |
# +================+=====================+====================================+
# | Bagging        |              0.9532 |                             0.6316 |
# +----------------+---------------------+------------------------------------+
# | Random Forests |              0.9766 |                             0.6316 |
# +----------------+---------------------+------------------------------------+
# | Extra Trees    |              0.9708 |                             0.6316 |
# +----------------+---------------------+------------------------------------+

# %%
num_train_samples = len(X_train)
num_test_samples = len(X_test)
print("Número de muestras de entrenamiento:", num_train_samples)
print("Número de muestras de prueba:", num_test_samples)
# Out:
# Número de muestras en el conjunto de entrenamiento: 398
